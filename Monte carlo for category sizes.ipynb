# %%
# %pylab inline
import cat100xxxxx as catreader
import plotcategories as pcat
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dfs = catreader.get50Categories(ref_date_i=2)

# %%
pcat.plotConfidence(dfs[17], method=4,std=.015)
# Out:
# Estimates lower/upper bound: (615173,811554)

# %%
pcat.plot5Ests(dfs,startindex=10, plotest=True, kde=True)
# Out:
# Estimated:533153, Actual:595836
# Estimated:627981, Actual:1071566
# Estimated:1079170, Actual:1359726
# Estimated:484514, Actual:577619
# Estimated:397711, Actual:421986

# %%
reload(pcat)
# Out:
# <module 'plotcategories' from 'plotcategories.py'>
