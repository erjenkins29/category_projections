# %% [markdown]
# ### P&G analysis document
#
# ##### Deadline
# Nov 9, 2016

# %% [markdown]
# ##### Scope
# Categories: [From Brian]
# - 1st priority: Hair Treatments, Shampoo, Conditioner
# - 2nd priority: Toothpaste, Face/Neck Care.  See below for more details
#
# Items: Products with a P&G brand.  Still an outstanding question.

# %% [markdown]
# ##### Definitions
# - $k$ = category
# - $i$ = index of a product
# - $M_k$ = number of products in category $k$
# - $c30_1$ = aggregated c30 number from mv_simtxn
# - $c30_2$ = allcomments_today - allcomments_30DaysAgo
# - $c$ =  a more reliable c30. Produced by combining c30_1 and c30_2
# - $X^{(k)}_{etype}$    = (features for stackers)
# - $\widetilde{X}^{(k)}_{etype}$    = $(c30_1, c30_2)$
# - $y^{(k)}_i$    = $q30_i$
# - $\widetilde{y}^{(k)}_i$    = $\displaystyle\sum_{i=1}^{M_k} q30_i$
# - $( \alpha^{(k)}_1 , \beta^{(k)}_1 )$ = parameters for Beta distribution fit to Tmall's q30 data on a particular month, category $k$
# - $( \alpha^{(k)}_2 , \beta^{(k)}_2 )$ = parameters for Beta distributon fit to Tmall's products (from 1 to n=30) sorted by c30 descending
# - $( \alpha^{(k)}_3 , \beta^{(k)}_3 )$ = parameters for Beta distributon fit to Tmall's products (from n=30 to $M_k$) sorted by c30 descending

# %% [markdown]
# ##### For each category $k$:
#
# - Verify inputs $X^{(k)}_{YHD} , \widetilde{X}^{(k)}_{YHD}$ are similar looking to $X^{(k)}_{Tmall} , \widetilde{X}^{(k)}_{Tmall}$

# %% [markdown]
# - $X^{(k)}_{YHD}$ => stacker models => output look reasonable

# %% [markdown]
# - Create a list of $( \alpha_k , \beta_k )$ for each month.  NOTE: should be highly correlated normal distributions sitting on a $y=mx$ line

# %% [markdown]
# - For each category in YHD, create a table of source categories from Tmall

# %% [markdown]
# - Monte Carlo using method 1 and 2 specified below

# %% [markdown]
# ##### Monte Carlo methods:
#
# Assumption is that category sizes can be simulated using the following model: $\sum q30 = \sum \frac{c30}{r}$ where $r = \frac{c30}{q30}$.
#
# We know that in general,
#
# $$r \sim Beta( \alpha, \beta)$$
#
# So we'll Monte Carlo over this distribution.  We also don't know for sure that this model from Tmall is the same as in YHD, so we will abstract $\alpha$ and $\beta$ according to how they waver as observed in Tmall.  So, the output will be a distribution of possible $\sum q30$ values, according to the assumptions that we've made in this model.
#
# Additionally, since data quality of c30 tends to worsen as the number of sales or comments increases, we'll want to account for this lack of understanding by using several methods
#
# - Method 1: fit $( \alpha^{(k)}_1 , \beta^{(k)}_1 )$ on r
# - Method 2: fit $( \alpha^{(k)}_2 , \beta^{(k)}_2 )$ on r's head, $( \alpha^{(k)}_3 , \beta^{(k)}_3 )$ on r's tail
#
# ##### Working directory:
#
# Update ipython notebooks in this directory, and use this notebook as a template for your work.  Copy it, and rename the notebook as "[category_name]".ipynb (don't use spaces in name)

# %% [markdown]
# ##### Scope
# priority 1: see below table

# %%
import pandas as pd
df = pd.read_csv('data.csv', encoding='gbk')
df[df.compass_cat_en.isin(["Conditioner","Shampoo","Hair Treatments"])&(df.platform_name_en.isin(["YHD","Tmall"]))].loc[:,["compass_cat_en","platform_name_en","platform_categ_l3_id","platform_categ_l3_cn","count_items"]]#.tolist()
# Out:
#       compass_cat_en platform_name_en  platform_categ_l3_id  \
# 415          Shampoo            Tmall              10030101
# 416          Shampoo              YHD              20010401
# 426      Conditioner            Tmall              10030201
# 428      Conditioner            Tmall              10030301
# 430      Conditioner            Tmall              10030401
# 432      Conditioner            Tmall              10030501
# 433      Conditioner              YHD              20010402
# 459  Hair Treatments            Tmall              10030201
# 461  Hair Treatments            Tmall              10030301
# 463  Hair Treatments            Tmall              10030401
# 465  Hair Treatments            Tmall              10030501
# 466  Hair Treatments              YHD              20010402
# 467  Hair Treatments              YHD              20010403
#
#     platform_categ_l3_cn  count_items
# 415                  洗发水         4618
# 416                  洗发水         6251
# 426                  护发素         1660
# 428                发膜/倒模         1014
# 430                免洗护发素          361
# 432               洗发护发套装         1257
# 433                护发/润发         5303
# 459                  护发素         1660
# 461                发膜/倒模         1014
# 463                免洗护发素          361
# 465               洗发护发套装         1257
# 466                护发/润发         5303
# 467                 洗护套装         3730

# %% [markdown]
# priority 2: see below table

# %%
df[df.compass_cat_en.isin(["Face/Neck Care", "Toothpaste"])&(df.platform_name_en.isin(["YHD","Tmall"]))].loc[:,["compass_cat_en","platform_name_en","platform_categ_l3_id","platform_categ_l3_cn","count_items"]]#.tolist()
# Out:
#       compass_cat_en platform_name_en  platform_categ_l3_id  \
# 91    Face/Neck Care            Tmall              10010101
# 93    Face/Neck Care            Tmall              10010201
# 95    Face/Neck Care            Tmall              10010301
# 97    Face/Neck Care            Tmall              10010401
# 99    Face/Neck Care            Tmall              10010501
# 101   Face/Neck Care            Tmall              10010601
# 103   Face/Neck Care            Tmall              10010701
# 105   Face/Neck Care            Tmall              10010801
# 107   Face/Neck Care            Tmall              10010901
# 109   Face/Neck Care            Tmall              10011001
# 111   Face/Neck Care            Tmall              10011101
# 113   Face/Neck Care            Tmall              10011201
# 115   Face/Neck Care            Tmall              10011202
# 117   Face/Neck Care            Tmall              10011203
# 119   Face/Neck Care            Tmall              10011204
# 121   Face/Neck Care            Tmall              10011205
# 123   Face/Neck Care            Tmall              10011206
# 125   Face/Neck Care            Tmall              10011207
# 127   Face/Neck Care            Tmall              10011208
# 129   Face/Neck Care            Tmall              10011209
# 131   Face/Neck Care            Tmall              10011210
# 133   Face/Neck Care            Tmall              10011211
# 135   Face/Neck Care            Tmall              10012101
# 136   Face/Neck Care              YHD              20010101
# 137   Face/Neck Care              YHD              20010102
# 138   Face/Neck Care              YHD              20010103
# 139   Face/Neck Care              YHD              20010104
# 140   Face/Neck Care              YHD              20010105
# 141   Face/Neck Care              YHD              20010106
# 142   Face/Neck Care              YHD              20010107
# 143   Face/Neck Care              YHD              20010108
# 144   Face/Neck Care              YHD              20010109
# 145   Face/Neck Care              YHD              20010110
# 146   Face/Neck Care              YHD              20010111
# 147   Face/Neck Care              YHD              20010112
# 148   Face/Neck Care              YHD              20010113
# 149   Face/Neck Care              YHD              20010201
# 150   Face/Neck Care              YHD              20010202
# 151   Face/Neck Care              YHD              20010203
# 152   Face/Neck Care              YHD              20010204
# 153   Face/Neck Care              YHD              20010301
# 1272      Toothpaste            Tmall             100500301
# 1273      Toothpaste              YHD              20010601
#
#      platform_categ_l3_cn  count_items
# 91                     洁面         7439
# 93               面部磨砂/去角质         1100
# 95                  面部按摩霜          422
# 97                化妆水/爽肤水         6622
# 99                   面部精华         1988
# 101                 乳液/面霜        11139
# 103                    面膜         6201
# 105                面部护理套装        12580
# 107                  唇部护理         1828
# 109                  T区护理          920
# 111                  其他保养         1182
# 113                  男士洁面         2596
# 115                 男士爽肤水          745
# 117               男士乳液/面霜         1991
# 119                剃须膏/啫喱           70
# 121                   须后水           76
# 123               男士鼻帖/鼻膜           52
# 125                  男士面膜          573
# 127                男士面部精华          299
# 129                 男士润唇膏          290
# 131                其它男士护理           98
# 133                男士护理套装         1014
# 135                   珍珠膏          101
# 136                    面霜         6975
# 137                  护肤套装         6294
# 138               化妆水/爽肤水         5682
# 139                    洁面         5785
# 140                    面膜         9988
# 141                 乳液/凝胶         4532
# 142                  唇部护理         1207
# 143                    卸妆         1625
# 144                  面部精华         5020
# 145              面部磨砂/去角质          401
# 146                    喷雾          535
# 147                  T区护理          477
# 148                 面部按摩霜          158
# 149                男士面部护理         2223
# 150                  男士洁面         1504
# 151                男士护理套装         1139
# 152                  剃须护理         1165
# 153                  颈部护理           89
# 1272                   牙膏         9559
# 1273                   牙膏         4682
